# %% [markdown]
# ## Tarea 1

# %% [markdown]
# ### Pregunta 1

# %%
# !pip install tensorflow==2.0
# Out:
# Requirement already satisfied: tensorflow==2.0 in /usr/local/lib/python3.6/dist-packages (2.0.0)
# Requirement already satisfied: astor>=0.6.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.0) (0.8.1)
# Requirement already satisfied: six>=1.10.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.0) (1.12.0)
# Requirement already satisfied: tensorflow-estimator<2.1.0,>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.0) (2.0.1)
# Requirement already satisfied: keras-applications>=1.0.8 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.0) (1.0.8)
# Requirement already satisfied: keras-preprocessing>=1.0.5 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.0) (1.1.0)
# Requirement already satisfied: wheel>=0.26 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.0) (0.34.2)
# Requirement already satisfied: numpy<2.0,>=1.16.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.0) (1.18.3)
# Requirement already satisfied: protobuf>=3.6.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.0) (3.10.0)
# Requirement already satisfied: google-pasta>=0.1.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.0) (0.2.0)
# Requirement already satisfied: gast==0.2.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.0) (0.2.2)
# Requirement already satisfied: tensorboard<2.1.0,>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.0) (2.0.2)
# Requirement already satisfied: absl-py>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.0) (0.9.0)
# Requirement already satisfied: termcolor>=1.1.0 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.0) (1.1.0)
# Requirement already satisfied: wrapt>=1.11.1 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.0) (1.12.1)
# Requirement already satisfied: opt-einsum>=2.3.2 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.0) (3.2.1)
# Requirement already satisfied: grpcio>=1.8.6 in /usr/local/lib/python3.6/dist-packages (from tensorflow==2.0) (1.28.1)
# Requirement already satisfied: h5py in /usr/local/lib/python3.6/dist-packages (from keras-applications>=1.0.8->tensorflow==2.0) (2.10.0)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.6/dist-packages (from protobuf>=3.6.1->tensorflow==2.0) (46.1.3)
# Requirement already satisfied: google-auth-oauthlib<0.5,>=0.4.1 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.1.0,>=2.0.0->tensorflow==2.0) (0.4.1)
# Requirement already satisfied: requests<3,>=2.21.0 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.1.0,>=2.0.0->tensorflow==2.0) (2.23.0)
# Requirement already satisfied: google-auth<2,>=1.6.3 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.1.0,>=2.0.0->tensorflow==2.0) (1.7.2)
# Requirement already satisfied: werkzeug>=0.11.15 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.1.0,>=2.0.0->tensorflow==2.0) (1.0.1)
# Requirement already satisfied: markdown>=2.6.8 in /usr/local/lib/python3.6/dist-packages (from tensorboard<2.1.0,>=2.0.0->tensorflow==2.0) (3.2.1)
# Requirement already satisfied: requests-oauthlib>=0.7.0 in /usr/local/lib/python3.6/dist-packages (from google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.1.0,>=2.0.0->tensorflow==2.0) (1.3.0)
# Requirement already satisfied: idna<3,>=2.5 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard<2.1.0,>=2.0.0->tensorflow==2.0) (2.9)
# Requirement already satisfied: urllib3!=1.25.0,!=1.25.1,<1.26,>=1.21.1 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard<2.1.0,>=2.0.0->tensorflow==2.0) (1.24.3)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard<2.1.0,>=2.0.0->tensorflow==2.0) (2020.4.5.1)
# Requirement already satisfied: chardet<4,>=3.0.2 in /usr/local/lib/python3.6/dist-packages (from requests<3,>=2.21.0->tensorboard<2.1.0,>=2.0.0->tensorflow==2.0) (3.0.4)
# Requirement already satisfied: rsa<4.1,>=3.1.4 in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard<2.1.0,>=2.0.0->tensorflow==2.0) (4.0)
# Requirement already satisfied: pyasn1-modules>=0.2.1 in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard<2.1.0,>=2.0.0->tensorflow==2.0) (0.2.8)
# Requirement already satisfied: cachetools<3.2,>=2.0.0 in /usr/local/lib/python3.6/dist-packages (from google-auth<2,>=1.6.3->tensorboard<2.1.0,>=2.0.0->tensorflow==2.0) (3.1.1)
# Requirement already satisfied: oauthlib>=3.0.0 in /usr/local/lib/python3.6/dist-packages (from requests-oauthlib>=0.7.0->google-auth-oauthlib<0.5,>=0.4.1->tensorboard<2.1.0,>=2.0.0->tensorflow==2.0) (3.1.0)
# Requirement already satisfied: pyasn1>=0.1.3 in /usr/local/lib/python3.6/dist-packages (from rsa<4.1,>=3.1.4->google-auth<2,>=1.6.3->tensorboard<2.1.0,>=2.0.0->tensorflow==2.0) (0.4.8)

# %% [markdown]
# ##### Imports

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

import sklearn
from sklearn.utils import shuffle
from sklearn.neighbors import KNeighborsClassifier
from sklearn import preprocessing
from sklearn import linear_model
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score

import tensorflow as tf
from tensorflow import keras
from tensorflow.keras import layers

import os
import logging

# %%
os.environ['TF_CPP_MIN_VLOG_LEVEL'] = '0'
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3'



print(tf.__version__)
# Out:
# 2.0.0

# %% [markdown]
# #####Importe de dataset, se guardó el excel de la tarea en formato csv sin hacerle ninguna modificación, luego se identifican los tipos de datos en esta

# %%
dataset=pd.read_csv("dataset1.csv",sep=";")
dataset.dtypes
# Out:
# crr_Nom                      object
# psu_Nem                       int64
# psu_Leng                      int64
# psu_Mate                      int64
# psu_Cie                       int64
# psu_Pond                      int64
# Longitud                    float64
# Latitud                     float64
# cred_apr                      int64
# distancia                   float64
# F                             int64
# M                             int64
# PARTICULAR_SUBVENCIONADO      int64
# PARTICULAR_PAGADO             int64
# MUNICIPAL                     int64
# cluster                      object
# dtype: object

# %% [markdown]
# ##### Los datos categoricos se pasan a numericos y la columna de carreras (crr_Nom) se transforma en columnnas dummy para cada carrera

# %%
dataset['crr_Nom']=pd.Categorical(dataset['crr_Nom'])
dataset['crr_Nom']=dataset.crr_Nom.cat.codes

dataset['Longitud']=pd.Categorical(dataset['Longitud'])
dataset['Longitud']=dataset.Longitud.cat.codes

dataset['Latitud']=pd.Categorical(dataset['Latitud'])
dataset['Latitud']=dataset.Latitud.cat.codes

dataset['cluster']=pd.Categorical(dataset['cluster'])
dataset['cluster']=dataset.cluster.cat.codes

dataset=pd.get_dummies(dataset, drop_first=True,columns=['crr_Nom'])

dataset.dtypes
# Out:
# psu_Nem                       int64
# psu_Leng                      int64
# psu_Mate                      int64
# psu_Cie                       int64
# psu_Pond                      int64
# Longitud                      int16
# Latitud                       int16
# cred_apr                      int64
# distancia                   float64
# F                             int64
# M                             int64
# PARTICULAR_SUBVENCIONADO      int64
# PARTICULAR_PAGADO             int64
# MUNICIPAL                     int64
# cluster                        int8
# crr_Nom_1                     uint8
# crr_Nom_2                     uint8
# crr_Nom_3                     uint8
# crr_Nom_4                     uint8
# crr_Nom_5                     uint8
# crr_Nom_6                     uint8
# crr_Nom_7                     uint8
# crr_Nom_8                     uint8
# crr_Nom_9                     uint8
# crr_Nom_10                    uint8
# crr_Nom_11                    uint8
# crr_Nom_12                    uint8
# crr_Nom_13                    uint8
# dtype: object

# %%
dataset.head()
# Out:
#    psu_Nem  psu_Leng  psu_Mate  ...  crr_Nom_11  crr_Nom_12  crr_Nom_13
# 0      783       653       685  ...           0           0           0
# 1      799       705       713  ...           0           0           0
# 2      688       543       612  ...           0           1           0
# 3      605       598       658  ...           0           0           0
# 4      603       710       668  ...           0           0           0
#
# [5 rows x 28 columns]

# %% [markdown]
# ##### Se establecen los sample para testeo y entrenamiento

# %%
train_dataset = dataset.sample(frac=0.8,random_state=0)
test_dataset = dataset.drop(train_dataset.index)

# %%
sns.pairplot(train_dataset[['cluster','cred_apr','psu_Mate','distancia']], diag_kind="kde",hue='cluster')

# %% [markdown]
# ##### Revision de estadisticas generales

# %%
train_stats = train_dataset.describe()
train_stats.pop('cluster')
train_stats = train_stats.transpose()
train_stats
# Out:
#                            count        mean  ...         75%         max
# psu_Nem                   6293.0  668.304147  ...  723.000000  826.000000
# psu_Leng                  6293.0  618.440172  ...  660.000000  831.000000
# psu_Mate                  6293.0  670.424122  ...  702.000000  850.000000
# psu_Cie                   6293.0  623.086127  ...  661.000000  850.000000
# psu_Pond                  6293.0  659.822183  ...  693.000000  822.000000
# Longitud                  6293.0  111.485301  ...  159.000000  245.000000
# Latitud                   6293.0  123.728905  ...  168.000000  245.000000
# cred_apr                  6293.0   18.153981  ...   33.000000   40.000000
# distancia                 6293.0   33.311633  ...   86.263468  136.283837
# F                         6293.0    0.219132  ...    0.000000    1.000000
# M                         6293.0    0.780868  ...    1.000000    1.000000
# PARTICULAR_SUBVENCIONADO  6293.0    0.522326  ...    1.000000    1.000000
# PARTICULAR_PAGADO         6293.0    0.244399  ...    0.000000    1.000000
# MUNICIPAL                 6293.0    0.233275  ...    0.000000    1.000000
# crr_Nom_1                 6293.0    0.127125  ...    0.000000    1.000000
# crr_Nom_2                 6293.0    0.021929  ...    0.000000    1.000000
# crr_Nom_3                 6293.0    0.081042  ...    0.000000    1.000000
# crr_Nom_4                 6293.0    0.061497  ...    0.000000    1.000000
# crr_Nom_5                 6293.0    0.059272  ...    0.000000    1.000000
# crr_Nom_6                 6293.0    0.071667  ...    0.000000    1.000000
# crr_Nom_7                 6293.0    0.069601  ...    0.000000    1.000000
# crr_Nom_8                 6293.0    0.099793  ...    0.000000    1.000000
# crr_Nom_9                 6293.0    0.071190  ...    0.000000    1.000000
# crr_Nom_10                6293.0    0.069283  ...    0.000000    1.000000
# crr_Nom_11                6293.0    0.076593  ...    0.000000    1.000000
# crr_Nom_12                6293.0    0.079294  ...    0.000000    1.000000
# crr_Nom_13                6293.0    0.033688  ...    0.000000    1.000000
#
# [27 rows x 8 columns]

# %% [markdown]
# ##### Se separa la variable o etiqueta objetivo del resto de los datasets de entrenamiento y testeo

# %%
train_labels = train_dataset.pop('cluster')
test_labels = test_dataset.pop('cluster')

# %% [markdown]
# ##### Se normalizan las variables  para q tengan la misma escala

# %%
def norm(x):
    return (x - train_stats['mean']) / train_stats['std']
normed_train_data = norm(train_dataset)
normed_test_data = norm(test_dataset)

# %% [markdown]
# ##### Contruccion del modelo
# ###### Se establece un modelo con 2 hidden layers de 13 nodos cada una

# %%
def build_model():
      
      
    model = keras.Sequential([
    layers.Dense(13, activation='relu', input_shape=[len(train_dataset.keys())]),
    layers.Dense(13, activation='relu'),
    layers.Dense(1)
  ])

    optimizer = tf.keras.optimizers.RMSprop(0.001)

    model.compile(loss='mse',
                optimizer=optimizer,
                metrics=['mae', 'mse'])
    return model

# %%
model = build_model()

# %%
model.summary()
# Out:
# Model: "sequential_12"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_34 (Dense)             (None, 13)                364
# _________________________________________________________________
# dense_35 (Dense)             (None, 13)                182
# _________________________________________________________________
# dense_36 (Dense)             (None, 1)                 14
# =================================================================
# Total params: 560
# Trainable params: 560
# Non-trainable params: 0
# _________________________________________________________________

# %%
example_batch = normed_train_data[:10]
example_result = model.predict(example_batch)
example_result
# Out:
# WARNING:tensorflow:Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <class 'NoneType'>
# array([[1.6570501 ],
#        [0.6662803 ],
#        [0.41074035],
#        [1.4940138 ],
#        [0.03093185],
#        [0.8299848 ],
#        [0.08881305],
#        [0.04224157],
#        [1.7923871 ],
#        [0.97759974]], dtype=float32)

# %%
class PrintDot(keras.callbacks.Callback):
    def on_epoch_end(self, epoch, logs):
        if epoch % 100 == 0: print('')
        print('.', end='')

EPOCHS = 1000

history = model.fit(
  normed_train_data, train_labels,
  epochs=EPOCHS, validation_split = 0.2, verbose=0,
  callbacks=[PrintDot()])
# Out:
# WARNING:tensorflow:Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <class 'NoneType'>
#
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................
# ....................................................................................................

# %%
hist = pd.DataFrame(history.history)
hist['epoch'] = history.epoch
hist.tail()
# Out:
#          loss       mae       mse  val_loss   val_mae   val_mse  epoch
# 995  0.116577  0.250348  0.116577  0.185679  0.313730  0.185679    995
# 996  0.116439  0.250679  0.116439  0.185453  0.311190  0.185453    996
# 997  0.116356  0.249886  0.116356  0.184285  0.313103  0.184285    997
# 998  0.116300  0.250887  0.116300  0.185291  0.315032  0.185291    998
# 999  0.116178  0.250251  0.116178  0.182068  0.310136  0.182068    999

# %%
def plot_history(history):

    hist = pd.DataFrame(history.history)
    hist['epoch'] = history.epoch

    plt.figure()
    plt.xlabel('Epoch')
    plt.ylabel('Mean Abs Error [Cluster]')
    plt.plot(hist['epoch'], hist['mae'],
               label='Train Error')
    plt.plot(hist['epoch'], hist['val_mae'],
               label = 'Val Error')
    plt.ylim([0,.8])
    plt.legend()

    plt.figure()
    plt.xlabel('Epoch')
    plt.ylabel('Mean Square Error [$cluster^2$]')
    plt.plot(hist['epoch'], hist['mse'],
               label='Train Error')
    plt.plot(hist['epoch'], hist['val_mse'],
              label = 'Val Error')
    plt.ylim([0,.6])
    plt.legend()
    plt.show()
    
plot_history(history)

# %%
model = build_model()

early_stop = keras.callbacks.EarlyStopping(monitor='val_loss', patience=10)

history = model.fit(normed_train_data, train_labels, epochs=EPOCHS,
                    validation_split = 0.2, verbose=0, callbacks=[early_stop, PrintDot()])

plot_history(history)
# Out:
# WARNING:tensorflow:Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <class 'NoneType'>
#
# .........................................................................

# %%
loss, mae, mse = model.evaluate(normed_test_data, test_labels, verbose=2)

print("Testing set Mean Abs Error: {:5.2f} cluster".format(mae))
# Out:
# WARNING:tensorflow:Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <class 'NoneType'>
# 1573/1573 - 0s - loss: 0.1783 - mae: 0.3182 - mse: 0.1783
# Testing set Mean Abs Error:  0.32 cluster

# %%
test_predictions = model.predict(normed_test_data).flatten()

plt.scatter(test_labels, test_predictions)
plt.xlabel('True Values [cluster]')
plt.ylabel('Predictions [cluster]')
plt.axis('equal')
plt.axis('square')
plt.xlim([-1,plt.xlim()[1]])
plt.ylim([-1,plt.ylim()[1]])
_ = plt.plot([-100, 100], [-100, 100])
# Out:
# WARNING:tensorflow:Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <class 'NoneType'>

# %%
error = test_predictions - test_labels
plt.hist(error, bins = 25)
plt.xlabel("Prediction Error [cluster]")
_ = plt.ylabel("Count")

# %%
y_pred=[]
y_test=(test_labels.values.tolist())
test_predictions=list(test_predictions)
for i in range(len(test_predictions)):
  y_pred.append(int(round(test_predictions[i])))

# %%
print(confusion_matrix(y_test,y_pred))
# Out:
# [[210  45   0   0   0]
#  [ 34 605 105   0   0]
#  [  0  40 284  25   0]
#  [  0   3 103 116   3]
#  [  0   0   0   0   0]]

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.7724094087730451

# %%
f1_score(y_test,y_pred, average='micro')
# Out:
# 0.7724094087730451

# %% [markdown]
# ### Pregunta 2

# %%
dataset=pd.read_csv('dataset2.csv')
dataset.dtypes
# Out:
# x            float64
# y            float64
# condition      int64
# dtype: object

# %%
train_dataset = dataset.sample(frac=0.8,random_state=0)
test_dataset = dataset.drop(train_dataset.index)

# %%
sns.pairplot(train_dataset[['condition','x','y']], diag_kind="kde",hue='condition')

# %%
train_stats = train_dataset.describe()
train_stats.pop('condition')
train_stats = train_stats.transpose()
train_stats
# Out:
#      count          mean  ...           75%           max
# x  65318.0 -3.284569e+03  ...  4.854059e+04  1.424726e+05
# y  65318.0  5.838861e+06  ...  5.938792e+06  6.025505e+06
#
# [2 rows x 8 columns]

# %%
train_labels = train_dataset.pop('condition')
test_labels = test_dataset.pop('condition')

# %%
def norm(x):
    return (x - train_stats['mean']) / train_stats['std']
normed_train_data = norm(train_dataset)
normed_test_data = norm(test_dataset)

# %%
def build_model():
      
      
    model = keras.Sequential([
    layers.Dense(1, activation='relu', input_shape=[len(train_dataset.keys())]),
    layers.Dense(1,activation='sigmoid')
  ])

    optimizer = tf.keras.optimizers.RMSprop(0.001)

    model.compile(loss='mse',
                optimizer=optimizer,
                metrics=['accuracy'])
    return model

# %%
model=build_model()
model.summary()
# Out:
# Model: "sequential_15"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# dense_43 (Dense)             (None, 1)                 3
# _________________________________________________________________
# dense_44 (Dense)             (None, 1)                 2
# =================================================================
# Total params: 5
# Trainable params: 5
# Non-trainable params: 0
# _________________________________________________________________

# %%
history=model.fit(normed_train_data,train_labels, batch_size=10, epochs=10,validation_split=.2)
hist = pd.DataFrame(history.history)
hist['epoch'] = history.epoch
hist.tail()
# Out:
# WARNING:tensorflow:Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <class 'NoneType'>
# Train on 52254 samples, validate on 13064 samples
# Epoch 1/10
# 52254/52254 [==============================] - 7s 130us/sample - loss: 0.1520 - accuracy: 0.8034 - val_loss: 0.1400 - val_accuracy: 0.8020
# Epoch 2/10
# 52254/52254 [==============================] - 7s 129us/sample - loss: 0.1389 - accuracy: 0.8034 - val_loss: 0.1392 - val_accuracy: 0.8020
# Epoch 3/10
# 52254/52254 [==============================] - 7s 129us/sample - loss: 0.1385 - accuracy: 0.8034 - val_loss: 0.1389 - val_accuracy: 0.8020
# Epoch 4/10
# 52254/52254 [==============================] - 7s 129us/sample - loss: 0.1384 - accuracy: 0.8034 - val_loss: 0.1388 - val_accuracy: 0.8020
# Epoch 5/10
# 52254/52254 [==============================] - 7s 133us/sample - loss: 0.1384 - accuracy: 0.8034 - val_loss: 0.1388 - val_accuracy: 0.8020
# Epoch 6/10
# 52254/52254 [==============================] - 7s 140us/sample - loss: 0.1384 - accuracy: 0.8034 - val_loss: 0.1388 - val_accuracy: 0.8020
# Epoch 7/10
# 52254/52254 [==============================] - 7s 131us/sample - loss: 0.1383 - accuracy: 0.8034 - val_loss: 0.1388 - val_accuracy: 0.8020
# Epoch 8/10
# 52254/52254 [==============================] - 7s 131us/sample - loss: 0.1383 - accuracy: 0.8034 - val_loss: 0.1387 - val_accuracy: 0.8020
# Epoch 9/10
# 52254/52254 [==============================] - 7s 134us/sample - loss: 0.1383 - accuracy: 0.8034 - val_loss: 0.1389 - val_accuracy: 0.8020
# Epoch 10/10
# 52254/52254 [==============================] - 7s 129us/sample - loss: 0.1384 - accuracy: 0.8034 - val_loss: 0.1388 - val_accuracy: 0.8020
#        loss  accuracy  val_loss  val_accuracy  epoch
# 5  0.138366  0.803422  0.138796      0.801975      5
# 6  0.138347  0.803422  0.138792      0.801975      6
# 7  0.138343  0.803422  0.138687      0.801975      7
# 8  0.138316  0.803422  0.138893      0.801975      8
# 9  0.138353  0.803422  0.138821      0.801975      9

# %%
def plot_history(history):
  
  hist = pd.DataFrame(history.history)
  hist['epoch'] = history.epoch

  plt.figure()
  plt.xlabel('Epoch')
  plt.ylabel('loss')
  plt.plot(hist['epoch'], hist['loss'],
               label='Train Error')
  plt.plot(hist['epoch'], hist['val_loss'],
               label = 'Val Error')
  
  plt.ylim([0,.2])
  plt.legend()

  plt.figure()
  plt.xlabel('Epoch')
  plt.ylabel('accuracy')
  plt.plot(hist['epoch'], hist['accuracy'],
               label='Train Error')
  plt.plot(hist['epoch'], hist['val_accuracy'],
              label = 'Val Accuracy')
  
  plt.ylim([0.5,1])
  plt.legend()
  plt.show()
    
plot_history(history)

# %%
test_predictions=model.predict(normed_test_data).flatten()
# Out:
# WARNING:tensorflow:Falling back from v2 loop because of error: Failed to find data adapter that can handle input: <class 'pandas.core.frame.DataFrame'>, <class 'NoneType'>

# %%
y_pred=[]
y_test=(test_labels.values.tolist())
test_predictions=list(test_predictions)
for i in range(len(test_predictions)):
  y_pred.append(int(round(test_predictions[i])))
print(confusion_matrix(y_test,y_pred))
# Out:
# [[13127     0]
#  [ 3202     0]]

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.8039071590421949

# %%
f1_score(y_test,y_pred,average='micro')
# Out:
# 0.803907159042195
